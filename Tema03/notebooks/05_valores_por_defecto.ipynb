# %% [markdown]
# # Laboratorio 5. Valores por defecto y objetos mutables
#
# > **Uso en VS Code**: selecciona el kernel del entorno virtual del tema (`.venv`) antes de ejecutar.
# >
# > Al inicio del Notebook te preguntará en la parte superior por el kernel de python que se va a usar. Selecciona el del venv
# >
# > Ejecuta las celdas de forma progresiva. Puedes modificar valores y volver a ejecutar una celda para observar el resultado.
# >
# > En los notebooks evitamos entradas interactivas con `input()` para no bloquear el kernel.
# > Los ejemplos usan valores definidos directamente en las celdas.

# %% [markdown]
# ## 1. Valores por defecto
#
# Un parámetro puede tener un valor por defecto. Si no se pasa ese argumento, Python usa el valor definido en la cabecera de la función.

# %%
def crear_alerta(mensaje, nivel="INFO", notificar=False):
    """
    Crea un texto de alerta con nivel y opción de notificación.

    Args:
        mensaje: Texto principal de la alerta.
        nivel: Nivel de severidad. Por defecto, INFO.
        notificar: Indica si debe añadirse una marca de aviso.

    Returns:
        Texto de alerta formateado.
    """
    texto = f"[{nivel}] {mensaje}"
    if notificar:
        texto += " -> enviar aviso"
    return texto

# %% [markdown]
# ## 2. Llamadas usando valores por defecto y valores explícitos
#
# La primera llamada usa los valores por defecto. La segunda los sobrescribe con argumentos con nombre.

# %%
print(crear_alerta("Servicio iniciado"))
print(crear_alerta("Disco lleno", nivel="CRITICO", notificar=True))

# %% [markdown]
# ## 3. Ejemplo no recomendado: lista como valor por defecto
#
# Las listas son mutables. Si se usan como valor por defecto, se crean una sola vez al definir la función y pueden conservar datos entre llamadas.

# %%
def agregar_evento_mal(evento, historial=[]):
    """
    Ejemplo no recomendado: usa una lista mutable como valor por defecto.

    Args:
        evento: Evento que se añadirá.
        historial: Lista de eventos.

    Returns:
        Lista de eventos acumulada de forma implícita.
    """
    historial.append(evento)
    return historial


print("Mal construido:")
print(agregar_evento_mal("arranque"))
print(agregar_evento_mal("parada"))
print(agregar_evento_mal("reinicio"))

# %% [markdown]
# ## 4. Forma recomendada: `None` como valor por defecto
#
# Usamos `None` para indicar que no se recibió una lista externa. Si hace falta, la lista se crea dentro de la función.

# %%
def agregar_evento(evento, historial=None):
    """
    Añade un evento a una lista recibida o crea una lista temporal.

    Args:
        evento: Evento que se añadirá.
        historial: Lista opcional de eventos.

    Returns:
        Lista con el evento añadido.
    """
    if historial is None:
        historial = []
    historial.append(evento)
    return historial

# %% [markdown]
# ## 5. Llamadas independientes
#
# Como no pasamos una lista externa, cada llamada crea una lista temporal distinta.

# %%
print("Bien construido, llamadas independientes:")
print(agregar_evento("arranque"))
print(agregar_evento("parada"))

# %% [markdown]
# ## 6. Historial externo controlado
#
# Si queremos acumular valores, creamos la lista fuera y la pasamos explícitamente.

# %%
print("Bien construido, historial externo controlado:")
historico_eventos = []
print(agregar_evento("arranque", historico_eventos))
print(agregar_evento("parada", historico_eventos))

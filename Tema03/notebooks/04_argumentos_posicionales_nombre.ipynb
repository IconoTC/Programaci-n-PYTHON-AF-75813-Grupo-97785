# %% [markdown]
# # Laboratorio 4. Argumentos posicionales y argumentos con nombre
#
# > **Uso en VS Code**: selecciona el kernel del entorno virtual del tema (`.venv`) antes de ejecutar.
# >
# > Al inicio del Notebook te preguntará en la parte superior por el kernel de python que se va a usar. Selecciona el del venv
# >
# > Ejecuta las celdas de forma progresiva. Puedes modificar valores y volver a ejecutar una celda para observar el resultado.
# >
# > En los notebooks evitamos entradas interactivas con `input()` para no bloquear el kernel.
# > Los ejemplos usan valores definidos directamente en las celdas.

# %% [markdown]
# ## 1. Argumentos posicionales
#
# Los argumentos posicionales se asignan a los parámetros por orden. Esto es simple, pero puede ser ambiguo si hay varios valores del mismo tipo.

# %%
def crear_usuario(nombre, grupo, activo):
    """
    Construye una descripción simple de usuario.

    Args:
        nombre: Nombre del usuario.
        grupo: Grupo asignado.
        activo: Estado lógico del usuario.

    Returns:
        Cadena descriptiva del usuario.
    """
    return f"{nombre} -> {grupo} -> activo={activo}"

# %% [markdown]
# ## 2. Orden correcto e incorrecto
#
# La segunda llamada no falla, pero el resultado no tiene sentido porque el orden de los argumentos es incorrecto.

# %%
print(crear_usuario("ana", "operadores", True))
print(crear_usuario("operadores", "ana", True))

# %% [markdown]
# ## 3. Argumentos con nombre
#
# Los argumentos con nombre hacen explícito qué valor corresponde a cada parámetro.

# %%
def programar_tarea(nombre, hora, habilitada):
    """
    Construye una descripción de una tarea planificada.

    Args:
        nombre: Nombre de la tarea.
        hora: Hora de ejecución.
        habilitada: Estado de activación.

    Returns:
        Cadena con la planificación.
    """
    return f"{nombre} a las {hora}, habilitada={habilitada}"

# %% [markdown]
# ## 4. Cambiar el orden con seguridad
#
# Al usar nombres, el orden de los argumentos puede variar sin cambiar el significado de la llamada.

# %%
print(programar_tarea(nombre="backup", hora="02:00", habilitada=True))
print(programar_tarea(habilitada=False, hora="03:00", nombre="limpieza"))

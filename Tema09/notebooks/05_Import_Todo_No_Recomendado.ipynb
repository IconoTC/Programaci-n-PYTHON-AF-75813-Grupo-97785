# %% [markdown]
# # Tema 9 - Laboratorio 5: importación con `*`
#
# Ejemplo funcional, pero no recomendable.

# %% [markdown]
# ## 1. Objetivo
#
# Comprobar que `from modulo import *` funciona, pero no es recomendable como práctica habitual.

# %% [markdown]
# ## 2. Ejecutar el código completo
#
# La celda contiene el código de `04_import_todo_no_recomendado.py` dentro del heredoc.

# %%
# %%bash
# cd ../src
# python - <<'PY'
# """
# Tema 9 - Módulos
# Laboratorio 4: importar todo con *.
#
# Objetivo:
#     Mostrar que import * funciona, pero no es recomendable en código
#     profesional porque oculta el origen de los nombres importados.
# """
#
# # Evitar esta forma salvo casos muy justificados.
# from validaciones import *
#
# puerto = 443
#
# if puerto_valido(puerto):
#     print("Puerto correcto")
#
# servicio = normalizar_servicio(" SsH ")
# print("Servicio normalizado:", servicio)
#
# estado = " error "
# print("Estado válido:", estado_valido(estado))
# PY

# %% [markdown]
# ## 3. Interpretación
#
# El código funciona, pero oculta el origen de los nombres importados. En scripts profesionales es preferible `import validaciones` o importar recursos concretos.

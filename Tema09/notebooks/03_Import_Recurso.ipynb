# %% [markdown]
# # Tema 9 - Laboratorio 3: importar recursos concretos
#
# Uso de `from validaciones import puerto_valido`.

# %% [markdown]
# ## 1. Objetivo
#
# Importar un recurso concreto desde un módulo con `from modulo import recurso`.

# %% [markdown]
# ## 2. Ejecutar el código completo
#
# La celda contiene el código de `02_import_recurso.py` dentro del heredoc.

# %%
# %%bash
# cd ../src
# python - <<'PY'
# """
# Tema 9 - Módulos
# Laboratorio 2: importar recursos concretos.
#
# Objetivo:
#     Importar solo una función concreta desde un módulo.
# """
#
# from validaciones import puerto_valido
#
# if puerto_valido(22):
#     print("ssh válido")
#
# # Esta línea generaría NameError porque normalizar_servicio
# # no se ha importado en este script.
# # servicio = normalizar_servicio(" SsH ")
# # print(servicio)
# PY

# %% [markdown]
# ## 3. Interpretación
#
# Solo queda disponible el nombre importado (`puerto_valido`). Si se intenta usar `normalizar_servicio` sin importarlo, se produciría `NameError`.

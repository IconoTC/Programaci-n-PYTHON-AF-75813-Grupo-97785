# %% [markdown]
# # Tema 08 — Operaciones de entrada-salida
#
# **Programación Python · Laboratorio Guiado**
#
# Este notebook reproduce el laboratorio en pasos progresivos. Ejecuta las celdas en orden para mantener las variables y ficheros generados por cada ejercicio.

# %% [markdown]
# ## Laboratorio 1. Operaciones previas con pathlib.Path
#
# **Objetivo:** Practicar creación de rutas, comprobaciones, creación de directorios, lectura/escritura simple, renombrado, eliminación y búsqueda por patrón.

# %% [markdown]
# ### 1. Preparación del entorno
#
# En la terminal, actualiza el repositorio, entra en la carpeta del tema, activa el entorno virtual y abre Visual Studio Code.
#
# ```bash
# git pull origin main
# cd ~/Curso_Python/Tema08
# source .venv/bin/activate
# python --version
# code .
# ```
#
# En el notebook trabajaremos con rutas relativas y se creará la carpeta `Tema08/data` cuando sea necesario.

# %% [markdown]
# ### 2. Crear rutas con `Path`
#
# Abrir el fichero `01_pathlib_rutas.py`. Revisar la creación de rutas con `Path` y la diferencia entre ruta relativa y ruta absoluta.

# %%
from pathlib import Path

print("=== 1. Crear rutas con Path ===")
carpeta = Path("../data")
ruta = carpeta / "pathlib_demo.txt"
print("Carpeta relativa:", carpeta)
print("Ruta relativa:", ruta)
print("Ruta absoluta:", ruta.resolve())

# %% [markdown]
# ### 3. Crear el directorio de trabajo
#
# Crear el directorio si no existe y comprobar el tipo de recurso con `exists()` e `is_dir()`.

# %%
print("\n=== 2. Crear directorio si no existe ===")
carpeta.mkdir(parents=True, exist_ok=True)
print("Carpeta existe:", carpeta.exists())
print("Carpeta es directorio:", carpeta.is_dir())
print("Fichero existe antes de escribir:", ruta.exists())

# %% [markdown]
# ### 4. Escribir y leer texto con métodos de `Path`
#
# Usar `write_text()` y `read_text()` para escribir y leer texto sin abrir el fichero explícitamente con `open()`.

# %%
print("\n=== 3. Escribir y leer texto con métodos de Path ===")
ruta.write_text("ssh:22\nnginx:443\n", encoding="utf-8")
print("Fichero existe después de escribir:", ruta.exists())
print("Es fichero:", ruta.is_file())
print("Extensión:", ruta.suffix)
print("Contenido:")
print(ruta.read_text(encoding="utf-8").strip())

# %% [markdown]
# ### 5. Cambiar el nombre del fichero
#
# Cambiar el nombre usando `with_name()` para construir la nueva ruta y `rename()` para renombrar el fichero.

# %%
print("\n=== 4. Cambiar nombre con with_name() y rename() ===")
nueva_ruta = ruta.with_name("pathlib_demo_renamed.txt")
if nueva_ruta.exists():
    nueva_ruta.unlink()
ruta.rename(nueva_ruta)
print("Ruta original existe:", ruta.exists())
print("Ruta renombrada existe:", nueva_ruta.exists())

# %% [markdown]
# ### 6. Eliminar el fichero temporal
#
# Eliminar el fichero renombrado con `unlink()`.

# %%
print("\n=== 5. Limpiar fichero temporal ===")
if nueva_ruta.exists():
    nueva_ruta.unlink()
print("Ruta renombrada existe tras unlink:", nueva_ruta.exists())

# %% [markdown]
# ### 7. Localizar ficheros por patrón
#
# Listar ficheros CSV del directorio `data` con `glob()`.

# %%
print("\n=== 6. Listar ficheros CSV del directorio data ===")
for fichero in carpeta.glob("*.csv"):
    print("CSV encontrado:", fichero.name)

# %% [markdown]
# ### 8. Ejecución del script completo
#
# Desde la terminal, el mismo laboratorio se puede ejecutar como script completo:
#
# ```bash
# python 01_pathlib_rutas.py
# ```
#
# **Resultado esperado:** el alumno debe manejar rutas, crear directorios, comprobar recursos, escribir/leer texto sencillo, renombrar, eliminar y localizar ficheros por patrón.

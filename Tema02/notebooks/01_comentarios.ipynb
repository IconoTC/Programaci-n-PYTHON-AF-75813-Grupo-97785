# %% [markdown]
# # Laboratorio 1. Comentarios y docstrings
#
# > **Uso en VS Code**: selecciona el kernel del entorno virtual del tema (`.venv`) antes de ejecutar.
# >
# > Al inicio del Notebook te preguntará en la parte superior por el kernel de python que se va a usar. Selecciona el del venv
# >
# > Ejecuta las celdas de forma progresiva. Puedes modificar valores y volver a ejecutar una celda para observar el resultado.
# >
# > En los notebooks evitamos entradas interactivas con `input()` para no bloquear el kernel.
# > Los ejemplos usan valores definidos directamente en las celdas.

# %% [markdown]
# ## Objetivo
# Identificar la diferencia entre docstrings, comentarios de línea y código ejecutable.
#
# Los docstrings son cadenas de texto delimitadas con triples comillas. En este ejemplo se usan como cabecera explicativa del script.

# %%
'''
    Los comentarios en bloque o Docstring permiten un bloque
    de texto largo delimitando 3 comillas simples o dobles
    al principio y cerrando con las mismas comillas al final.
'''

# %%
""" Esto es otro ejemplo de Docstring
    pero en este caso con comillas dobles.
    Pueden ser útiles en la cabecera de un código Python
    para documentar lo que hace el programa.
"""

# %% [markdown]
# ## Comentarios de línea
# Cualquier texto situado a la derecha de `#` se considera comentario y no se ejecuta.

# %%
# Cualquier cadena a la derecha de un carácter almohadilla
# se considera un comentario.
print('Este print se ejecuta y te saludo, el resto está todo comentado')  # A partir de aquí es un comentario
# print('Este print no se ejecuta porque está comentado')

# %% [markdown]
# ## Prueba
# Quita el símbolo `#` de la última línea y vuelve a ejecutar la celda para comprobar qué cambia.

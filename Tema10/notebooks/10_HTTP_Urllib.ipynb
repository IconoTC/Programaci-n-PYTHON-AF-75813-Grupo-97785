# %% [markdown]
# # Laboratorio 10. HTTP básico con urllib
#
# Petición HTTP sencilla con `urllib`, controlando timeout y errores. Requiere salida a Internet; si no hay conexión, debe fallar de forma controlada.

# %% [markdown]
# ## 1. Preparar rutas del tema

# %%
from pathlib import Path


def localizar_tema10() -> Path:
    """Localiza el directorio Tema10 aunque el notebook se ejecute desde notebooks, Tema10 o Curso_Python."""
    actual = Path.cwd().resolve()
    candidatos = [
        actual,
        actual.parent,
        actual / "Tema10",
        actual.parent / "Tema10",
    ]

    for candidato in candidatos:
        if candidato.name == "Tema10" and candidato.exists():
            return candidato
        if (candidato / "src").exists() and (candidato / "notebooks").exists():
            return candidato

    raise RuntimeError("No se ha podido localizar el directorio Tema10. Abre el notebook desde Tema10/notebooks o desde el proyecto Curso_Python.")


base_dir = localizar_tema10()
src_dir = base_dir / "src"
data_dir = base_dir / "data"
output_dir = base_dir / "output"
backup_dir = base_dir / "backup"
log_dir = base_dir / "logs"

for directorio in (data_dir, output_dir, backup_dir, log_dir):
    directorio.mkdir(parents=True, exist_ok=True)

print("base_dir:", base_dir)
print("data_dir:", data_dir)

# %% [markdown]
# ## 2. Importar módulos

# %%
from urllib.request import urlopen
from urllib.error import URLError
import json

# %% [markdown]
# ## 3. Ejecutar petición HTTP con timeout

# %%
url = "https://api.ipify.org?format=json"
print("URL:", url)

try:
    with urlopen(url, timeout=5) as respuesta:
        datos = json.load(respuesta)
        print("Conexión exitosa.")
        print("IP pública detectada:", datos["ip"])
except URLError as error:
    print("No se pudo conectar con la API.")
    print("Motivo:", error.reason)
except TimeoutError:
    print("La petición superó el tiempo de espera.")

# %% [markdown]
# # Tema 7 — Gestión de errores
# ## Laboratorio 3: validación, EAFP y raise
#
# **Objetivo**
#
# Comparar LBYL y EAFP, usar `raise` para indicar estados inválidos y validar datos dentro de funciones.
#
# **Indicaciones de uso**
#
# Ejecuta las celdas en orden. Algunas celdas incluyen líneas comentadas para provocar errores de forma controlada; descoméntalas solo cuando el instructor lo indique.

# %% [markdown]
# > Directorio de trabajo recomendado: `~/Curso_Python/Tema07`
# > Entorno virtual recomendado: `.venv` con prompt `Tema07`.

# %% [markdown]
# ## 1. LBYL: comprobar antes de operar
#
# LBYL significa *Look Before You Leap*: comprobar antes de intentar la operación.

# %%
puertos = {"ssh": 22, "nginx": 443}
servicio = "api"

if servicio in puertos:
    print(puertos[servicio])
else:
    print("Servicio no registrado.")

# %% [markdown]
# ## 2. EAFP: intentar y capturar si falla
#
# EAFP significa *Easier to Ask Forgiveness than Permission*: intentar la operación y capturar el fallo esperado.

# %%
try:
    print(puertos[servicio])
except KeyError:
    print("Servicio no registrado.")

# %% [markdown]
# ## 3. Acceso seguro con `get()`
#
# `get()` permite devolver un valor alternativo cuando la clave no existe.

# %%
print(puertos.get(servicio, "Servicio no registrado."))

# %% [markdown]
# ## 4. Lanzar excepciones con `raise`
#
# Una función puede rechazar explícitamente valores fuera del rango permitido.

# %%
def validar_puerto(puerto):
    """
    Valida que un puerto esté en el rango permitido.

    Raises:
        ValueError: si el puerto está fuera de rango.
    """
    if not 1 <= puerto <= 65535:
        raise ValueError("Puerto fuera de rango")
    return puerto


print(validar_puerto(443))

# Descomenta para comprobar el error:
# print(validar_puerto(70000))

# %% [markdown]
# ## 5. Validación dentro de funciones
#
# La función comprueba sus argumentos antes de construir el resultado.

# %%
def crear_endpoint(servicio: str, puerto: int) -> str:
    """
    Construye un endpoint servicio:puerto.

    Raises:
        ValueError: si el servicio está vacío o el puerto está fuera de rango.
    """
    if not servicio:
        raise ValueError("Servicio vacío")
    if not 1 <= puerto <= 65535:
        raise ValueError("Puerto fuera de rango")
    return f"{servicio}:{puerto}"


print(crear_endpoint("ssh", 22))

# Descomenta para comprobar los errores:
# print(crear_endpoint("", 22))
# print(crear_endpoint("ssh", 70000))

# %% [markdown]
# ## 6. Validación al procesar colecciones
#
# Un dato incorrecto no debe detener necesariamente el procesamiento completo.

# %%
datos = ["22", "ssh", "443", "70000"]
validos = []
rechazados = []

for valor in datos:
    try:
        validos.append(validar_puerto(int(valor)))
    except ValueError as error:
        rechazados.append((valor, str(error)))

print("Válidos:", validos)
print("Rechazados:", rechazados)

# %% [markdown]
# ## Cierre del laboratorio 3
#
# Comprueba que entiendes qué excepción se produce en cada caso, qué bloque la captura y por qué el programa puede continuar ejecutándose.

# %% [markdown]
# # Laboratorio 2. Listas multidimensionales
#
# > **Uso en VS Code**: selecciona el kernel del entorno virtual del tema (`.venv`) antes de ejecutar.
# >
# > Ejecuta las celdas en orden. Puedes modificar valores y volver a ejecutar una celda para observar el resultado.
# >
# > El código está separado en pasos para reproducir progresivamente el laboratorio del script `.py`.

# %% [markdown]
# ## 1. Lista de listas como tabla sencilla
#
# Una lista puede contener otras listas. Se accede con `[fila][columna]`.

# %%
estado_hosts = [
    ["srv01", "OK", 22],
    ["srv02", "FALLO", 80],
    ["srv03", "OK", 443],
]

print("Host de la primera fila:", estado_hosts[0][0])
print("Estado de la segunda fila:", estado_hosts[1][1])
print("Puerto de la tercera fila:", estado_hosts[2][2])

# %% [markdown]
# ## 2. Recorrer filas completas
#
# Asignar cada posición a una variable mejora la lectura.

# %%
for fila in estado_hosts:
    host = fila[0]
    estado = fila[1]
    puerto = fila[2]
    print(f"{host} -> {estado}:{puerto}")

# %% [markdown]
# ## 3. Recorrer usando índices
#
# El recorrido por índices ayuda a entender la estructura, aunque puede ser menos legible.

# %%
for indice_fila in range(len(estado_hosts)):
    print("Fila:", indice_fila)

    for indice_columna in range(len(estado_hosts[indice_fila])):
        print("  Valor:", estado_hosts[indice_fila][indice_columna])

# %% [markdown]
# ## 4. Matriz irregular
#
# Las filas no tienen por qué tener la misma longitud. Aquí se usa slicing para separar el host de sus servicios.

# %%
servicios_por_host = [
    ["srv01", "ssh", "nginx"],
    ["srv02", "ssh"],
    ["srv03", "ssh", "postgresql", "backup"],
]

for fila in servicios_por_host:
    host = fila[0]
    servicios = fila[1:]
    print(f"{host} tiene servicios: {servicios}")

# %% [markdown]
# ## 5. Alternativa más legible con diccionarios
#
# Si los campos tienen nombre, suele ser más claro usar diccionarios.

# %%
inventario = [
    {"host": "srv01", "estado": "OK", "puerto": 22},
    {"host": "srv02", "estado": "FALLO", "puerto": 80},
    {"host": "srv03", "estado": "OK", "puerto": 443},
]

for equipo in inventario:
    print(f"{equipo['host']} -> {equipo['estado']}:{equipo['puerto']}")

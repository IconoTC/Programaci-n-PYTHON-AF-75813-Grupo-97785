# %% [markdown]
# # Laboratorio 4A. Encapsulación básica
#
# > **Uso en VS Code**: selecciona el kernel del entorno virtual del tema (`.venv`) antes de ejecutar.
# >
# > Ejecuta las celdas de forma progresiva. Puedes modificar valores y volver a ejecutar una celda para observar el resultado.
# >
# > En estos notebooks, las partes que en el script `.py` aparecen comentadas se han separado en celdas independientes para facilitar la ejecución paso a paso.

# %% [markdown]
# ## 1. Convención de uso interno y name mangling
#
# Un guion bajo inicial indica uso interno por convención. El doble guion bajo aplica *name mangling* y dificulta el acceso directo.

# %%
class Servicio:
    def __init__(self, nombre, puerto):
        self.nombre = nombre
        self._activo = False
        self.__puerto = puerto

    def iniciar(self):
        self._activo = True

    def get_activo(self):
        return self._activo

    def get_puerto(self):
        return self.__puerto


MiServicio1 = Servicio("ssh", 22)
MiServicio1.iniciar()
print(MiServicio1.nombre)
print(MiServicio1.get_activo())
print(MiServicio1.get_puerto())
print(MiServicio1._activo)

# %% [markdown]
# ## 2. Acceso directo a `__puerto`
#
# En el script esta línea está comentada porque provoca `AttributeError`. En el notebook la dejamos separada para que el alumno pueda probarla conscientemente.

# %%
# Descomenta la línea siguiente para comprobar el error:
# print(MiServicio1.__puerto)

# %% [markdown]
# ## 3. Idea clave
#
# Python no impone privacidad absoluta. La encapsulación en Python combina convenciones, propiedades y validación.

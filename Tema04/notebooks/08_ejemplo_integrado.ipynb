# %% [markdown]
# # Laboratorio 8. Ejemplo integrado: servidor, interfaz y servicios
#
# > **Uso en VS Code**: selecciona el kernel del entorno virtual del tema (`.venv`) antes de ejecutar.
# >
# > Ejecuta las celdas de forma progresiva. Puedes modificar valores y volver a ejecutar una celda para observar el resultado.
# >
# > En estos notebooks, las partes que en el script `.py` aparecen comentadas se han separado en celdas independientes para facilitar la ejecución paso a paso.

# %% [markdown]
# ## 1. Clase `InterfazRed`
#
# Representa una interfaz de red. El método `__str__()` devuelve una representación legible.

# %%
class InterfazRed:
    """Representa una interfaz de red de un servidor."""

    def __init__(self, nombre, ip):
        self.nombre = nombre
        self.ip = ip

    def __str__(self):
        return f"{self.nombre} ({self.ip})"

# %% [markdown]
# ## 2. Clase base `Servicio`
#
# Incluye atributo de clase, propiedades, métodos de instancia y representación textual mediante `__str__()`.

# %%
class Servicio:
    """Clase base para servicios del sistema."""

    categoria = "servicio"

    def __init__(self, nombre, activo=False):
        self.nombre = nombre
        self.activo = activo

    @property
    def nombre(self):
        return self._nombre

    @nombre.setter
    def nombre(self, valor):
        self._nombre = valor.strip().lower()

    def iniciar(self):
        self.activo = True

    def comprobar(self):
        estado = "OK" if self.activo else "DETENIDO"
        return f"{self.nombre}: {estado}"

    def __str__(self):
        return self.comprobar()

# %% [markdown]
# ## 3. Clase hija `ServicioWeb`
#
# Especializa `Servicio`, reutiliza `super().__init__()` y añade validación del puerto mediante propiedad.

# %%
class ServicioWeb(Servicio):
    """Servicio especializado con un puerto TCP asociado."""

    def __init__(self, nombre, puerto, activo=False):
        super().__init__(nombre, activo)
        self.puerto = puerto

    @property
    def puerto(self):
        return self._puerto

    @puerto.setter
    def puerto(self, valor):
        if not 1 <= valor <= 65535:
            raise ValueError("Puerto no válido")
        self._puerto = valor

    def comprobar(self):
        estado = "OK" if self.activo else "DETENIDO"
        return f"{self.nombre}:{self.puerto} -> {estado}"

# %% [markdown]
# ## 4. Clase `Servidor`
#
# Un servidor se compone de una interfaz de red y varios servicios. La lista de servicios se usa aquí de forma sencilla; se estudiará más a fondo en el tema de colecciones.

# %%
class Servidor:
    """Servidor compuesto por una interfaz de red y varios servicios."""

    def __init__(self, hostname, interfaz):
        self.hostname = hostname
        self.interfaz = interfaz
        self.servicios = []

    def agregar_servicio(self, servicio):
        self.servicios.append(servicio)

    def resumen(self):
        print(f"Servidor: {self.hostname}")
        print(f"Red: {self.interfaz}")
        for servicio in self.servicios:
            print("-", servicio.comprobar())

# %% [markdown]
# ## 5. Crear objetos y ejecutar el resumen
#
# Aquí se integran instancias, composición, herencia, propiedades y polimorfismo básico.

# %%
interfaz = InterfazRed("eth0", "10.0.0.20")
servidor = Servidor("srv-web-01", interfaz)

ssh = Servicio("  SSH  ", True)
web = ServicioWeb("nginx", 443, True)
api = ServicioWeb("api", 8080, False)

servidor.agregar_servicio(ssh)
servidor.agregar_servicio(web)
servidor.agregar_servicio(api)

servidor.resumen()

# %% [markdown]
# ## 6. Modificación progresiva
#
# En el script `.py` esta parte aparece comentada para activarla en un segundo paso. Aquí se ejecuta como celda independiente.

# %%
api.iniciar()
servidor.resumen()

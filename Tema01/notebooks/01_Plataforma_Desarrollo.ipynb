# %% [markdown]
# # Tema 1 - Plataforma de desarrollo Python
#
# Notebook de comprobación del entorno usado en el laboratorio.

# %% [markdown]
# ## Objetivo
# Verificar que Visual Studio Code ejecuta este notebook con el kernel del entorno virtual del proyecto.

# %%
import sys, os, platform
print("Notebook ejecutado correctamente")
print("Ejecutable:", sys.executable)
print("Directorio:", os.getcwd())
print("Sistema:", platform.platform())

# %% [markdown]
# ## Comprobación opcional de dependencias
# Ejecutar esta celda después de instalar `requests` en el entorno virtual.

# %%
import requests
print("requests:", requests.__version__)
